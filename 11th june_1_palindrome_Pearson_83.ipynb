# %% [markdown]
# #### Write a function that returns True or False depending on whether the given number is a palindrome.
#
# A palindromic number is a number that remains the same when its digits are reversed

# %%
n = int(input("Enter the number please "))
c = 0
while n != 0:
    a = n % 10
    c += a
    n = n / 10
print(n)
print(c)
# Out:
# 0.0
# 6.666666666666668

# %%
123/10
# Out:
# 12.3

# %%
123%10
# Out:
# 2.3000000000000007

# %% [markdown]
# #### We can do the work in **strings** which will not work here

# %%
seen = ''

string_ = input("Enter the string: ")
for char in string_:
    if char not in seen:
        seen = seen + char
        # seen.add(char)

# if palindrome or not
# if string_ == seen:
# print(string_ == seen)
print(seen)
# Out:
# 17

# %% [markdown]
# #### Chatgpt code

# %%
# Original number
num = 123

# Step-by-step breakdown
a = num % 10  # Last digit (3)
num = num // 10  # Remove the last digit, num becomes 12

b = num % 10  # New last digit (2)
num = num // 10  # Remove the last digit, num becomes 1

c = num % 10  # New last digit (1)
num = num // 10  # num becomes 0, though we no longer need it

# Output the stored variables
print(f"a: {a}, b: {b}, c: {c}")
# Out:
# a: 3, b: 2, c: 1

# %% [markdown]
# ## Now my code in work, given we use **//**

# %%
n = int(input("Enter the number please "))
integer_ = n
c = 0
while n != 0:
    a = n % 10
    c = c * 10 + a
    n = n // 10
# print(n)
# print(c)
    
print(integer_ == c)
# Out:
# True

# %%
123 % 10
# Out:
# 3

# %%
123 // 10
# Out:
# 12

# %% [markdown]
# ## This above code is working fine yay.
