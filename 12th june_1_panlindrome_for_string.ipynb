# %%
seen = "" # () - this is tuple, this won't work, we need string

string_ = input("Enter the string: ")
for char in string_:
    # print(char)
    seen = seen + char

print(seen)

print(string_ == seen)
# Out:
# hgfgh
# True
