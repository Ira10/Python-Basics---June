# %% [markdown]
# # Functions

# %% [markdown]
# ## 1. Built-in Function
#
# 1. **Input** - invoking 'input' function to take user input.
# 2. **Eval** - evaluating a string

# %%
eval('10+15')
# Out:
# 25

# %%
eval('10'+'15')
# Out:
# 1015

# %% [markdown]
# #### Exercise

# %%
a = 5
b = 8

def sum(a,b):
    if a or b !=0:
        sum_=a+b
    return sum_

# print(sum(4,5))

print(sum)
# Out:
# <function sum at 0x1046dbf60>

# %%
# Print the function name
print(sum.__name__)

# Print the result of the function
print(sum(a, b))
# Out:
# sum
# 13

# %%
p = int(input())
q =int(input())

# Print the result of the function
print(sum(p, q))
# Out:
# 100
