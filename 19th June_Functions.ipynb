# %% [markdown]
# # Functions

# %% [markdown]
# ## 1. Built-in Function
#
# 1. **Input** - invoking 'input' function to take user input.
# 2. **Eval** - evaluating a string

# %%
eval('10+15')
# Out:
# 25

# %%
eval('10'+'15')
# Out:
# 1015
